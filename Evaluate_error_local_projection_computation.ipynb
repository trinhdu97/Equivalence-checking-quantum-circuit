# %%
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import random_unitary
from qiskit.circuit.library import UnitaryGate
from qiskit.circuit.library import RZGate
from qiskit.quantum_info import Operator
import numpy as np
import json
from qiskit.quantum_info import SparsePauliOp
from qiskit.quantum_info import Pauli
import os
import matplotlib.pyplot as plt
import itertools
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.quantum_info import DensityMatrix, partial_trace, Operator
import numpy as np

import Create_quantum_circuit
import Manipulate_layers
import time
import local_projection_computation
import Evaluate_error_local_projection_computation

# %% [markdown]
# ### This is the reproduction of FIG 7. Note that the number of patterns in the paper is 100, it takes more time. But in fact, one pattern can give a similar figure because the value plotted are average values over many local projection matrices.

# %%
n_qubits=300 # Number of qubits in the circuits
min_depth=1
max_depth=3
n_patterns=3 # Number of random circuits to generate


Evaluate_error_local_projection_computation.run_and_record_errors_for_random_circuits(n_qubits=n_qubits, min_depth=min_depth, max_depth=max_depth,
                                                                                      output_file_path="Evaluation_Artifact_Error_equivalence_checking.txt",
                                                                                      n_patterns=n_patterns)

Evaluate_error_local_projection_computation.plot_log_errors_from_file(file_path="Evaluation_Artifact_Error_equivalence_checking.txt",
                                                                      output_file="Evaluation_Artifact_Error_equivalence_checking.pdf",n_qubits=n_qubits,n_patterns=n_patterns)
# Out:
# Running 3 trials for depth = 1
#
# Running 3 trials for depth = 2
#
# Running 3 trials for depth = 3
#
# All results written to Evaluation_Artifact_Error_equivalence_checking.txt

# %% [markdown]
# ## Here is the submitted FIG 7

# %%
n_qubits = 300  # Number of qubits in the circuits
n_patterns = 100  # Number of random circuits to generate
Evaluate_error_local_projection_computation.plot_log_errors_from_file(file_path='SUBMITTED_Error_equivalence_checking.txt',
                                                                      output_file='SUBMITTED_FIG_7.pdf',
                                                                      n_qubits=n_qubits,
                                                                      n_patterns=n_patterns)
